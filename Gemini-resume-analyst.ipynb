# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha-2003git/Calcualator/blob/main/Gemini-resume-analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
import os

def query_gemini(prompt:str, api_key:str) -> str:
    """Query the Gemini API with a given prompt."""
    try:
        # Configure Gemini API
        genai.configure(api_key=api_key)

        # Initialize the model (adjust model name as per your Gemini API access)
        model = genai.GenerativeModel('gemini-1.5-flash')

        # Send the prompt
        response = model.generate_content(prompt)

        # Extract and return the response text
        if response and response.text:
            # logger.info("Successfully received response from Gemini API")
            return response.text.strip()
        else:
            # logger.error("No valid response from Gemini API")
            return "Error: No response received"

    except Exception as e:
        # logger.error(f"Error querying Gemini API: {str(e)}")
        return f"Error: {str(e)}"

def main():
    # Replace with your Gemini API key
    api_key = "AIzaSyCKFZnVm1FkbsBHXKE_-pz6zHQvwdqkE9U"

    # Define the prompt
    prompt = "What is 3 multiplied by 2?"


    # Query the Gemini API
    response = query_gemini(prompt, api_key)

    # Print the response
    print(f"Prompt: {prompt}")
    print(f"Response: {response}")

if __name__ == "__main__":
    main()
# Out:
# Prompt: What is 3 multiplied by 2?
# Response: 3 multiplied by 2 is 6.

# %%
import google.generativeai as genai

def query_gemini_resume_analysis(resume_text: str, job_description: str, api_key: str) -> str:
    """
    Analyze a resume against a job description using Gemini and return structured insights.
    """
    try:
        # Configure Gemini API
        genai.configure(api_key=api_key)

        # Initialize the Gemini model
        model = genai.GenerativeModel('gemini-1.5-flash')

        # Build the prompt
        prompt = f"""
You are an expert recruiter and resume analyst. Given the resume and job description below, perform a detailed analysis and provide the following structured output:

[RESUME]
{resume_text}

[JOB DESCRIPTION]
{job_description}

Return the analysis in this format:

1. **Summary of Resume**
2. **Education**
3. **Experience**
4. **Recent Industry Experience**
5. **Strengths and Weaknesses**
6. **Employment Stability**
7. **Roles and Responsibility Match**
8. **Hire Recommendation**

Use bullet points where appropriate. Be objective, concise, and highlight alignment or gaps clearly.
"""

        # Send the prompt
        response = model.generate_content(prompt)

        # Extract and return the response text
        if response and response.text:
            return response.text.strip()
        else:
            return "Error: No response received"

    except Exception as e:
        return f"Error: {str(e)}"
def main():
    api_key = "AIzaSyA3Ehcgnp6QUp7lKu-OOSWbn7hEA2LYnBY"

    # Sample inputs (replace with actual resume and JD)
    resume_text = """  ANUSHA KOMMU
                               +91 9603747149 | anushakommu3@gmail.com | LINKEDIN|GIT HUB
Objective
Aspiring software developer with a strong foundation in Python, JavaScript and full-stack web development.
Experienced in building responsive applications and machine learning models through academic projects.
Passionate about creating user-centric solutions and continuously learning technologies like cloud computing
and data analysis. Reliable team player with a proactive attitude and a keen eye for detail.
Technical Skills
• Frontend: HTML, CSS, Java Script
• Programming: C, Python and Core Java
• Database: MySQL
• Tools & IDEs: VS Code, Git, GitHub
• Operating System: Windows OS, Linux

Projects
Machine Learning for Identifying Diabetes Risk factors:
• Developed a machine learning model using Scikit-learn to predict diabetes from the PIMA Indian Diabetes
Dataset.
• Performed data preprocessing, feature selection, and implemented models like Logistic Regression and
Random Forest.
• Achieved 92% accuracy and evaluated performance using confusion matrix, precision, recall, and F1-score.
Rock-Paper-Scissors | Html, Css, JavaScript:
• Designed and developed a fully responsive ROCK-PAPER-SCISSORS website using HTML, CSS
and JavaScript.
• The site features a clean, modern design with smooth animations and transitions, showcasing skills.
Emphasized mobile-first design principles to ensure optimal viewing on all devices.


Education
DADI INSTITUTE OF ENGINEERING AND TECHNOLOGY 2021 -2025
B.Tech -CSE 8.18 CGPA
SIDDHARTHA JUNIOR COLLEGE 2019 -2021
Intermediate-MPC 9.5 CGPA
SAINT JUDE’S ENGLISH MEDIUM HIGH SCHOOL 2018 -2019
10th Class 9.7 CGPA
Certifications
• Azure Fundamentals by Microsoft.
• Web Development with HTML5, CSS3, and JavaScript by IBM.
• NPTEL Certified Java Programming with 53%.
• Data Analysis with Python, provided by IBM.
Internships
• Cybersecurity Virtual internship Dec-2022 - Feb 2023
• Process Mining Sep- Nov 2023
• Cloud Virtual internship Jan-Mar 2024
• Networking Cloud Virtual internship Jan-Mar 2025

Workshops
• Participated in one day virtual workshop on “Building our own social media Application
• Successfully completed workshop on “Hands on Git and GitHub” under DIET ACM student

Laungauges
• English
• Hindi
• Telugu

Declaration
I hereby declare that the above stated information is true to the best of my knowledge and belief.
K.ANUSHA."""
    job_description = """We are seeking a motivated and detail-oriented Software Developer with a strong foundation in Python, JavaScript, and full-stack web development. The ideal candidate is passionate about building responsive applications, working with machine learning models, and continuously learning emerging technologies such as cloud computing and data analysis.."""

    # Run the analysis
    result = query_gemini_resume_analysis(resume_text, job_description, api_key)

    # Display the result
    print(result)

if __name__ == "__main__":
    main()
# Out:
# **1. Summary of Resume:**
#
# Anusha Kommu's resume presents a recent graduate with a B.Tech in CSE, showcasing projects in machine learning and web development, along with several internships and certifications.  The resume highlights skills in Python, JavaScript, and database management, aligning with a typical entry-level software developer profile. However, the presentation needs improvement for clarity and impact.
#
#
# **2. Education:**
#
# * B.Tech in Computer Science and Engineering (CSE) from DADI Institute of Engineering and Technology (2021-2025) –  Good CGPA (8.18).
# * Relevant academic background strongly supports the target role.
#
#
# **3. Experience:**
#
# * **Projects:**  Two projects are listed – a machine learning project demonstrating practical application of skills and a simple web application.  However, more detail (e.g., technologies used, deployed URL or GitHub link) would significantly improve the impact.
# ...
